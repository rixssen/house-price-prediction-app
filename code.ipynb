# %%
import pandas as pd

# %%
df = pd.read_csv("mlproject1.csv")

# %%
df.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                                         int64
# Date                                       int64
# number of bedrooms                         int64
# number of bathrooms                      float64
# living area                                int64
# lot area                                   int64
# number of floors                         float64
# waterfront present                         int64
# number of views                            int64
# condition of the house                     int64
# grade of the house                         int64
# Area of the house(excluding basement)      int64
# Area of the basement                       int64
# Built Year                                 int64
# Renovation Year                            int64
# Postal Code                                int64
# Lattitude                                float64
# Longitude                                float64
# living_area_renov                          int64
# ...

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810635  42491                   4                 2.50         2920
# 1  6762810998  42491                   5                 2.75         2910
# 2  6762812605  42491                   4                 2.50         3310
# 3  6762812919  42491                   3                 2.00         2710
# 4  6762813105  42491                   3                 2.50         2600
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      4000               1.5                   0                0
# 1      9480               1.5                   0                0
# 2     42998               2.0                   0                0
# 3      4500               1.5                   0                0
# 4      4750               1.0                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df["Lattitude"] = df["Lattitude"].astype("int")

# %%
df["Longitude"] = df["Longitude"].astype("int")

# %%
df['number of bathrooms']= df['number of bathrooms'].astype(int)

# %%
df.dtypes
# Out:
# id                                       int64
# Date                                     int64
# number of bedrooms                       int64
# number of bathrooms                      int64
# living area                              int64
# lot area                                 int64
# number of floors                         int64
# waterfront present                       int64
# number of views                          int64
# condition of the house                   int64
# grade of the house                       int64
# Area of the house(excluding basement)    int64
# Area of the basement                     int64
# Built Year                               int64
# Renovation Year                          int64
# Postal Code                              int64
# Lattitude                                int64
# Longitude                                int64
# living_area_renov                        int64
# lot_area_renov                           int64
# ...

# %%
df["number of floors"] = df["number of floors"].astype(int)

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810635  42491                   4                    2         2920
# 1  6762810998  42491                   5                    2         2910
# 2  6762812605  42491                   4                    2         3310
# 3  6762812919  42491                   3                    2         2710
# 4  6762813105  42491                   3                    2         2600
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      4000                 1                   0                0
# 1      9480                 1                   0                0
# 2     42998                 2                   0                0
# 3      4500                 1                   0                0
# 4      4750                 1                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
columns = df.select_dtypes(include= 'number')

# %%
columns
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810635  42491                   4                    2
# 1      6762810998  42491                   5                    2
# 2      6762812605  42491                   4                    2
# 3      6762812919  42491                   3                    2
# 4      6762813105  42491                   3                    2
# ...           ...    ...                 ...                  ...
# 14614  6762830250  42734                   2                    1
# 14615  6762830339  42734                   3                    2
# 14616  6762830618  42734                   2                    1
# 14617  6762830709  42734                   4                    1
# 14618  6762831463  42734                   3                    1
#
#        living area  lot area  number of floors  waterfront present  \
# 0             2920      4000                 1                   0
# ...

# %%
df.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
df.drop(columns =["id" , "Date"] , inplace = True)

# %%
from matplotlib import pyplot as plt

# %%
df.corr()["Price"]
# Out:
# number of bedrooms                       0.308165
# number of bathrooms                      0.532031
# living area                              0.712276
# lot area                                 0.082117
# number of floors                         0.262649
# waterfront present                       0.263943
# number of views                          0.394954
# condition of the house                   0.040609
# grade of the house                       0.671805
# Area of the house(excluding basement)    0.615179
# Area of the basement                     0.330499
# Built Year                               0.050936
# Renovation Year                          0.133362
# Postal Code                             -0.115477
# Lattitude                                0.297570
# Longitude                                0.024807
# living_area_renov                        0.585021
# lot_area_renov                           0.075697
# Number of schools nearby                 0.009904
# ...

# %%
y = df["Price"]
x = df[["number of bathrooms" , "number of bedrooms" , "living area" , "number of views" , "grade of the house" ,"Area of the house(excluding basement)" , "Area of the basement"]]

# %%
x
# Out:
#        number of bathrooms  number of bedrooms  living area  number of views  \
# 0                     2.50                   4         2920                0
# 1                     2.75                   5         2910                0
# 2                     2.50                   4         3310                0
# 3                     2.00                   3         2710                0
# 4                     2.50                   3         2600                0
# ...                    ...                 ...          ...              ...
# 14614                 1.50                   2         1556                0
# 14615                 2.00                   3         1680                0
# 14616                 1.00                   2         1070                0
# 14617                 1.00                   4         1030                0
# 14618                 1.00                   3          900                0
#
# ...

# %%
df["Price"].plot(kind = "line")
# Out:
# <Axes: >

# %%
df["number of bedrooms"].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='number of bedrooms'>

# %%
df.groupby("number of bedrooms")["Price"].median().plot(kind = 'bar')
# Out:
# <Axes: xlabel='number of bedrooms'>

# %%
df[df["number of bedrooms"] == 8]
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 1511                    8                 3.50         4440      6480
# 4206                    8                 2.75         2790      6695
# 4657                    8                 2.75         4040     20666
# 7002                    8                 2.75         2530      4800
# 10167                   8                 6.00         4340      9415
# 10747                   8                 4.00         4020      7500
# 10915                   8                 4.00         7710     11750
# 13047                   8                 3.00         3840     15990
# 13443                   8                 5.00         2800      2580
# 13824                   8                 3.25         4300     10441
# 14219                   8                 3.75         3460      4600
#
#        number of floors  waterfront present  number of views  \
# 1511                2.0                   0                3
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y , test_size=0.2)

# %%
x_test
# Out:
#        number of bathrooms  number of bedrooms  living area  number of views  \
# 5490                  3.75                   3         3830                0
# 6422                  1.00                   5         1680                0
# 5352                  1.00                   5         1940                0
# 4659                  3.25                   3         3700                0
# 5320                  2.50                   3         3800                0
# ...                    ...                 ...          ...              ...
# 2549                  2.50                   4         3140                2
# 5756                  2.75                   4         2110                0
# 9968                  2.50                   4         2520                0
# 13139                 1.00                   2         1130                0
# 11756                 2.00                   4         2340                0
#
# ...

# %%
x_train
# Out:
#        number of bathrooms  number of bedrooms  living area  number of views  \
# 14483                 2.50                   5         3150                0
# 11412                 2.50                   4         2780                0
# 2609                  2.50                   4         3770                0
# 20                    2.50                   4         3310                0
# 7599                  1.00                   4         1610                0
# ...                    ...                 ...          ...              ...
# 11593                 2.50                   3         2040                0
# 4467                  2.25                   2         2290                0
# 1629                  3.25                   5         2900                0
# 8684                  1.00                   3         1020                0
# 543                   1.75                   4         2120                1
#
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
ln = LinearRegression()

# %%
ln.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_predict = ln.predict(x_test)

# %%
r2_score(y_test , y_predict)
# Out:
# 0.5850002738652875

# %%
tree = DecisionTreeRegressor()

# %%
tree.fit(x_train , y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = tree.predict(x_test)

# %%
mean_squared_error(y_test , y_pred)
# Out:
# 86585436498.9247

# %%
r2_score(y_test , y_pred)
# Out:
# 0.40020438494245714

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gb = GradientBoostingRegressor()

# %%
gb.fit(x_train , y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred = gb.predict(x_test)

# %%
mean_squared_error(y_test , y_pred)
# Out:
# 48287936944.97341

# %%
r2_score(y_test , y_pred)
# Out:
# 0.6654992570242473

# %%
import joblib
joblib.dump(gb ,"model.pkl")
# Out:
# ['model.pkl']

# %%
x_train.columns
# Out:
# Index(['number of bathrooms', 'number of bedrooms', 'living area',
#        'number of views', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement'],
#       dtype='object')
